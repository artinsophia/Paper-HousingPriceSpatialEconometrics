# %% [markdown]
# # 1.Loading

# %% [markdown]
# ### Industrial Park

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import numpy as np
import os

def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    
    try:
        import torch
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) 
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    except ImportError:
        pass


seed_everything(54)

# %%
file_path = '/mnt/data/raydata/政策-经济-建设/各级别产业园区信息（2025.7更新）/国家级、省级、区县级产业园区数据.xlsx'
park = pd.read_excel(file_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 file_path = '/mnt/data/raydata/政策-经济-建设/各级别产业园区信息（2025.7更新）/国家级、省级、区县级产业园区数据.xlsx'
# ----> 2 park = pd.read_excel(file_path)
#
# File ~/.conda/envs/Housing/lib/python3.10/site-packages/pandas/io/excel/_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
#     512         index_col=index_col,
#     513         usecols=usecols,
#     514         dtype=dtype,
#     515         converters=converters,
#     516         true_values=true_values,
#     517         false_values=false_values,
#     518         skiprows=skiprows,
#     519         nrows=nrows,
#     520         na_values=na_values,
#     521         keep_default_na=keep_default_na,
#     522         na_filter=na_filter,
#     523         verbose=verbose,
#     524         parse_dates=parse_dates,
#     525         date_parser=date_parser,
#     526         date_format=date_format,
#     527         thousands=thousands,
#     528         decimal=decimal,
#     529         comment=comment,
#     530         skipfooter=skipfooter,
#     531         dtype_backend=dtype_backend,
#     532     )
#     533 finally:
#     534     # make sure to close opened file handles
#     535     if should_close:
#
# File ~/.conda/envs/Housing/lib/python3.10/site-packages/pandas/io/excel/_base.py:1616, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1576 def parse(
#    1577     self,
#    1578     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1596     **kwds,
#    1597 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1598     """
#    1599     Parse specified sheet(s) into a DataFrame.
#    1600
#    (...)
#    1614     >>> file.parse()  # doctest: +SKIP
#    1615     """
# -> 1616     return self._reader.parse(
#    1617         sheet_name=sheet_name,
#    1618         header=header,
#    1619         names=names,
#    1620         index_col=index_col,
#    1621         usecols=usecols,
#    1622         converters=converters,
#    1623         true_values=true_values,
#    1624         false_values=false_values,
#    1625         skiprows=skiprows,
#    1626         nrows=nrows,
#    1627         na_values=na_values,
#    1628         parse_dates=parse_dates,
#    1629         date_parser=date_parser,
#    1630         date_format=date_format,
#    1631         thousands=thousands,
#    1632         comment=comment,
#    1633         skipfooter=skipfooter,
#    1634         dtype_backend=dtype_backend,
#    1635         **kwds,
#    1636     )
#
# File ~/.conda/envs/Housing/lib/python3.10/site-packages/pandas/io/excel/_base.py:778, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     775     sheet = self.get_sheet_by_index(asheetname)
#     777 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 778 data = self.get_sheet_data(sheet, file_rows_needed)
#     779 if hasattr(sheet, "close"):
#     780     # pyxlsb opens two TemporaryFiles
#     781     sheet.close()
#
# File ~/.conda/envs/Housing/lib/python3.10/site-packages/pandas/io/excel/_openpyxl.py:615, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     613 data: list[list[Scalar]] = []
#     614 last_row_with_data = -1
# --> 615 for row_number, row in enumerate(sheet.rows):
#     616     converted_row = [self._convert_cell(cell) for cell in row]
#     617     while converted_row and converted_row[-1] == "":
#     618         # trim trailing empty elements
#
# File ~/.conda/envs/Housing/lib/python3.10/site-packages/openpyxl/worksheet/_read_only.py:85, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      77 with self._get_source() as src:
#      78     parser = WorkSheetParser(src,
#      79                              self._shared_strings,
#      80                              data_only=self.parent.data_only,
#      81                              epoch=self.parent.epoch,
#      82                              date_formats=self.parent._date_formats,
#      83                              timedelta_formats=self.parent._timedelta_formats)
# ---> 85     for idx, row in parser.parse():
#      86         if max_row is not None and idx > max_row:
#      87             break
#
# File ~/.conda/envs/Housing/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:156, in parse()
#
# File ~/.conda/envs/Housing/lib/python3.10/xml/etree/ElementTree.py:1258, in iterparse.<locals>.iterator(source)
#    1256     if not data:
#    1257         break
# -> 1258     pullparser.feed(data)
#    1259 root = pullparser._close_and_return_root()
#    1260 yield from pullparser.read_events()
#
# File ~/.conda/envs/Housing/lib/python3.10/xml/etree/ElementTree.py:1296, in XMLPullParser.feed(self, data)
#    1294 if data:
#    1295     try:
# -> 1296         self._parser.feed(data)
#    1297     except SyntaxError as exc:
#    1298         self._events_queue.append(exc)
#
# File ~/.conda/envs/Housing/lib/python3.10/xml/etree/ElementTree.py:1718, in XMLParser.feed(self, data)
#    1716 """Feed encoded data to parser."""
#    1717 try:
# -> 1718     self.parser.Parse(data, False)
#    1719 except self._error as v:
#    1720     self._raiseerror(v)
#
# File /croot/python-split_1711037784081/work/Modules/pyexpat.c:423, in StartElement()
#
# File ~/.conda/envs/Housing/lib/python3.10/xml/etree/ElementTree.py:1646, in XMLParser._start(self, tag, attr_list)
#    1643 def _end_ns(self, prefix):
#    1644     return self.target.end_ns(prefix or '')
# -> 1646 def _start(self, tag, attr_list):
#    1647     # Handler for expat's StartElementHandler. Since ordered_attributes
#    1648     # is set, the attributes are reported as a list of alternating
#    1649     # attribute name,value.
#    1650     fixname = self._fixname
#    1651     tag = fixname(tag)
#
# KeyboardInterrupt:

# %%
def Display(df):
    print(f"Shape: {df.shape}")
    print(df.columns)
    missing_counts = df.isnull().sum()
    unique_counts = df.nunique()
    summary_df = pd.DataFrame({
        'Missing': missing_counts,
        'Unique': unique_counts,
        'Dtype': df.dtypes
    })
    display(summary_df)

    for col in df.columns:
        print(f"【col: {col}】")
        top_5 = df[col].value_counts().head(5)
        
        if top_5.empty:
            print("  (该列全为空或无有效数据)")
        else:
            for val, count in top_5.items():
                print(f"  - {val}: {count} 次")
        print("-" * 40)

# %%
Display(park)
# Out:
# Shape: (104129, 14)
# Index(['级别', '产业', '产业园名称', '简介', '位置', '经度', '纬度', '省份', '城市', '区县',
#        'Unnamed: 10', '更多数据请关注公众号', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')
#              Missing  Unique    Dtype
# 级别                 1       7   object
# 产业                 2      28   object
# 产业园名称              2  103676   object
# 简介                11  103262   object
# 位置                80    2511   object
# 经度               939   54531  float64
# 纬度               938   56203  float64
# 省份                80      33   object
# 城市              6800     438   object
# 区县             10207    2225   object
# Unnamed: 10   104129       0  float64
# 更多数据请关注公众号    104127       2   object
# Unnamed: 12   104129       0  float64
# Unnamed: 13   104123       3   object
# 【col: 级别】
#   - 其他: 90963 次
#   - 省级: 4444 次
#   - 区县级: 3866 次
#   - 乡镇级: 2052 次
#   - 国家级: 2045 次
# ----------------------------------------
# 【col: 产业】
#   - 其他: 93644 次
#   - 电子信息: 3033 次
#   - 文化创意: 1058 次
#   - 家电数码: 866 次
#   - 农林牧渔: 751 次
# ----------------------------------------
# 【col: 产业园名称】
#   - 涿州中关村和谷创新产业园: 14 次
#   - 安徽青年电子商务产业园: 12 次
#   - 青网科技园: 10 次
#   - 阿尔法智能制造产业园: 8 次
#   - 天山创谷平山产业园: 8 次
# ----------------------------------------
# 【col: 简介】
#   - 货运站距离： - 高铁距离： - 港口距离： - 机场距离： - 区位介绍： - 公路运输： - 铁路运输： - 园区周边房价： - 元/㎡两居室租金： - 元/月本市住房均价： - 元/㎡园区生活配套： - 居住环境： - 商业环境： - 超市： - 百货商场： - 酒店商务： - 休闲娱乐： - 医疗： - 教育： -: 150 次
#   - 货运站距离：1.成都站 18.6km 高铁距离：1.成都东站 28.1km 2.成都北站 18.7km 3.成都南站 25.6km 港口距离：1.成都西联钢铁物流港 18.8km 机场距离：1.成都双流国际机场 25.4km 区位介绍：保税区主要在西部园区，位于成都市主城区西北部，地处东经103°52′59″～103°58′57″，北纬30°43′17″～30°48′28″，与金牛区、青羊区、温江区和郫县接壤。公路运输：西部园区主要交通由“两纵四横”骨干路网及三条轨道交通组成，其中两纵为绕城高速、南北大道，四横为西芯大道(羊西线)、老成灌路、西源大道、货运大道。 铁路运输：在成都市区，离各火车站均近。园区周边房价：17758 元/㎡两居室租金：1500 元/月本市住房均价：9588 元/㎡园区生活配套：新建安置小区均按“10+1”标准同步配置了小学、幼儿园、农贸市场等公建配套设施。共建成公建配套项目约220个，包括社区服务中心、医疗卫生中心、养老助残中心等居住环境：截至2015年底，高新区已建成安置小区共计约1094万平米商业环境：各类配套齐全超市：欧尚、迪卡侬、华润万家、红旗、家乐福百货商场：万达广场(锦华店)、九方购物中心、凯德天府、苏宁广场城市奥特莱斯、王府井百货(科华店)酒店商务：成都首座万豪酒店、成都豪生大酒店、君豪酒店、成都华尔道夫酒店、三峡公寓休闲娱乐：高新文化中心开工建设、肖家河、新南、新北等一批以综合体形式集中建设的社区公建配套设施开工建设。截至2015年底，高新区已陆续建成锦城湖公园、锦江滨河公园、大源中央公园等项目，其余项目正加紧推进。医疗：成都市中西医结合医院、四川省肿瘤医院、四川省中西医结合医院教育：共建成并使用中小学、幼儿园等学校约98所。已建成蒙彼利埃小学、紫荆小学、大源Ⅷ线幼儿园、怡馨家园小学等一批学校及幼儿园。中和职中、保利心语南侧小学、中学、幼儿园等一批学校及幼儿园正在抓紧建设。: 96 次
#   - 货运站距离：10.0高铁距离：5.0港口距离：90.0机场距离：60.0区位介绍：坐落于宝坻区口东镇。位于天津市偏北方，距市区60公里；距天津机场60公里；距天津港90公里；距北京70公里。紧邻津蓟高速公路及潮白河左堤路、潮阳东路、宝黑公路等一级公路。公路运输：津蓟高速公路、宝平公路、津围公路贯穿宝坻区南北；京沈高速公路、大黑林路、京唐公路横贯东西；京沈高速和津蓟高速公路在城区交汇 铁路运输：津蓟铁路途径宝坻区境内。园区周边房价：6000.0 元/㎡两居室租金：1200.0 元/月本市住房均价：15000.0 元/㎡园区生活配套：园区周边建有公寓楼可提供解决住宿问题，周边依托宝坻城区现有住房居住环境：京津新城隶属于天津市宝坻区，2006年经国务院批准设立，是天津市在滨海新区开发开放战略中重点打造的十一座新城之一。城市定位为京津唐地区重要的休闲旅游服务中心，将打造成为以休闲度假、温泉疗养、会议会展、文化教育、总部经济、商业金融为特色的现代化卫星城市。经过几年的发展，已经形成独具魅力的产业特色，为打造社会主义京津冀一体化的先行区奠定了基础。玺悦峰、景瑞悦府、中航瑞景花园、龙熙府商业环境：宝坻目前商业环境主要以日常生活型消费为主，缺少大型、综合型商业综合体超市：城区劝宝超市及周边日用超市百货商场：百货大楼、宝坻新天地商业广场、宝坻怡购商业广场、东汇广场酒店商务：京津新城帝景温泉度假村、宝坻长城宾馆、宝坻宾馆、天津宝坻京津新城凯悦酒店、天津市宝坻区开发区大酒店休闲娱乐：京津新城帝景温泉度假村、 天天娱乐音乐广场医疗：宝坻区人民医院、宝坻区中医医院、宝坻区妇幼保健院教育：宝坻一中、宝坻四中、天津财经大学珠江学院、北京科技大学天津学院、解放军军事交通学院、天津医科大学临床医学院: 28 次
#   - 暂未填写: 27 次
#   - 货运站距离：2.0高铁距离：3.0港口距离：30.0机场距离：15.0区位介绍：天津西青精武镇吴庄子工业园紧邻团泊大道 津晋高速入口200米附近 津文公路赛达大道与毛条路交口 距中石油桥15分钟车程公路运输：位于天津市区南部，紧邻市中心。市政府8公里，区政府35公里，天津港30公里，天津海关9公里，天津国际机场15公里，首都国际机场150公里。 铁路运输：李港铁路园区周边房价：15000.0 元/㎡两居室租金：1500.0 元/月本市住房均价：25000.0 元/㎡园区生活配套：盛兴家园小区 鑫龙商业广场 佰思哲自选超市 天之福商务酒店 赛达采摘园居住环境：恒益隆庭 盛兴家园小区 开源里 祥和园 旭辉燕南园商业环境：鑫龙商业广场 精武国际商务广场超市：乐惠万家生活超市 佰思哲自选超市 世纪家旺福超市 佳客来超市百货商场：鑫龙商业广场 精武国际商务广场酒店商务：天之福商务酒店 天津金兰福泰宾馆 鑫龙快捷酒店 天福快捷酒店休闲娱乐：津涞洗浴 赛达采摘园医疗：蓝卡诊所 南河镇生殖健康服务分中心 济民医院 牛驼子卫生所 精武镇社区卫生服务中心教育：大南河小学 天津市西青区南河镇中心小学 天津师大富家湾幼儿园孙庄分园 天津公安警官职业学院 陈台子小学: 16 次
# ----------------------------------------
# 【col: 位置】
#   - 广东-深圳-宝安区: 4283 次
#   - 广东-东莞-东莞市: 3073 次
#   - 广东-深圳-龙岗区: 2927 次
#   - 上海: 2497 次
#   - 广东-深圳-龙华区: 2363 次
# ----------------------------------------
# 【col: 经度】
#   - 114.699310302734: 168 次
#   - 116.674522399902: 122 次
#   - 108.759834289551: 114 次
#   - 114.571723937988: 64 次
#   - 114.391563415527: 54 次
# ----------------------------------------
# 【col: 纬度】
#   - 38.280101776123: 168 次
#   - 39.5265464782715: 122 次
#   - 34.4364852905273: 114 次
#   - 38.1434135437012: 64 次
#   - 23.0922107696533: 54 次
# ----------------------------------------
# 【col: 省份】
#   - 广东: 31396 次
#   - 江苏: 12285 次
#   - 浙江: 10719 次
#   - 山东: 8276 次
#   - 福建: 4052 次
# ----------------------------------------
# 【col: 城市】
#   - 深圳: 11066 次
#   - 广州: 5090 次
#   - 佛山: 3626 次
#   - 东莞: 3336 次
#   - 苏州: 3193 次
# ----------------------------------------
# 【col: 区县】
#   - 宝安区: 4283 次
#   - 东莞市: 3073 次
#   - 龙岗区: 2927 次
#   - 龙华区: 2380 次
#   - 南海区: 1761 次
# ----------------------------------------
# 【col: Unnamed: 10】
#   (该列全为空或无有效数据)
# ----------------------------------------
# 【col: 更多数据请关注公众号】
#   - 【众鲤数据网】: 1 次
#   - 官网https://zldatas.com: 1 次
# ----------------------------------------
# 【col: Unnamed: 12】
#   (该列全为空或无有效数据)
# ----------------------------------------
# 【col: Unnamed: 13】
#   - 更多数据请关注公众号: 2 次
#   - 【众鲤数据网】: 2 次
#   - 官网https://zldatas.com: 2 次
# ----------------------------------------

# %%
trash_columns = ['Unnamed: 10', '更多数据请关注公众号', 'Unnamed: 12','Unnamed: 13']
park.drop(columns=trash_columns, inplace=True)

# %%
print(f"now the columns are {park.columns}")
# Out:
# now the columns are Index(['级别', '产业', '产业园名称', '简介', '位置', '经度', '纬度', '省份', '城市', '区县'], dtype='object')

# %% [markdown]
# ### Housing price

# %%
housing_path = '/mnt/data/raydata/房产/Housing_Sale_Listing_Rent/community_p/community.parquet'
housing = pd.read_parquet(housing_path)
Display(housing)
# Out:
# Shape: (317229, 28)
# Index(['名称', '城市', '区县', '板块', '参考均价', '环线位置', '小区地址', '物业类别', '建筑年代', '开发商',
#        '房屋总数', '楼栋总数', '物业公司', '绿 化 率', '容 积 率', '物 业 费', '建筑结构', '物业办公电话',
#        '产权描述', '供水', '供暖', '供电', '燃气费', '供热费', '停车位', '停车费用', 'baidu_coord_x',
#        'baidu_coord_y'],
#       dtype='object')
#                Missing  Unique    Dtype
# 名称                   0  278183   object
# 城市                   0      97   object
# 区县                   0    1020   object
# 板块                1243    5104   object
# 参考均价             77819   46637  float64
# 环线位置            263662      32   object
# 小区地址                12  301569   object
# 物业类别              9056    1372   object
# 建筑年代            123145    2603   object
# 开发商             132682   47763   object
# 房屋总数                76    6035   object
# 楼栋总数                66     523   object
# 物业公司            150734   39031   object
# 绿 化 率           107739    2343   object
# 容 积 率           106252    1342  float64
# 物 业 费           111916    9856   object
# 建筑结构             71152      15   object
# 物业办公电话          270728   18847   object
# 产权描述              9689    1496   object
# 供水               85941       3   object
# 供暖              183151       7   object
# 供电               83671       3   object
# 燃气费             117869    6131   object
# 供热费             228069    3579   object
# 停车位             124146    4735  float64
# 停车费用            135166    3799   object
# baidu_coord_x        0  314556  float64
# baidu_coord_y        0  314183  float64
# 【col: 名称】
#   - 阳光花园: 64 次
#   - 幸福家园: 63 次
#   - 锦绣花园: 59 次
#   - 粮食局宿舍: 42 次
#   - 和谐家园: 41 次
# ----------------------------------------
# 【col: 城市】
#   - 上海: 22092 次
#   - 成都: 18260 次
#   - 北京: 10945 次
#   - 重庆: 10104 次
#   - 苏州: 8625 次
# ----------------------------------------
# 【col: 区县】
#   - 浦东: 3659 次
#   - 顺德: 2216 次
#   - 城关区: 2083 次
#   - 鼓楼区: 2011 次
#   - 金水: 1893 次
# ----------------------------------------
# 【col: 板块】
#   - 老城区: 2106 次
#   - 火车站: 1624 次
#   - 魏都区: 1113 次
#   - 都江堰: 1101 次
#   - 海城区: 1060 次
# ----------------------------------------
# 【col: 参考均价】
#   - 60000.0: 57 次
#   - 50000.0: 51 次
#   - 55000.0: 43 次
#   - 68000.0: 41 次
#   - 40000.0: 38 次
# ----------------------------------------
# 【col: 环线位置】
#   - 外环外: 8494 次
#   - 内环内: 7878 次
#   - 二至三环: 6307 次
#   - 内环至中环: 4184 次
#   - 中环至外环: 3638 次
# ----------------------------------------
# 【col: 小区地址】
#   - 兴华中路: 56 次
#   - 太极大道: 50 次
#   - 浔峰洲路8号: 37 次
#   - 顺江大道: 34 次
#   - 黎明路: 33 次
# ----------------------------------------
# 【col: 物业类别】
#   - 普通住宅: 211943 次
#   - 普通住宅/底商: 14259 次
#   - 普通住宅/别墅: 10379 次
#   - 普通住宅/商业/底商: 8421 次
#   - 普通住宅/商业: 8348 次
# ----------------------------------------
# 【col: 建筑年代】
#   - 2000年: 6292 次
#   - 1998年: 4064 次
#   - 1995年: 2804 次
#   - 2005年: 2688 次
#   - 1999年: 2418 次
# ----------------------------------------
# 【col: 开发商】
#   - 无开发商: 18551 次
#   - 无: 6910 次
#   - 陕西亿润经贸有限公司: 3315 次
#   - 重庆汇东房地产开发有限公司: 2835 次
#   - 物业和度娘都不知道开发商名称: 2033 次
# ----------------------------------------
# 【col: 房屋总数】
#   - 1户: 12901 次
#   - 2户: 5096 次
#   - 24户: 3656 次
#   - 36户: 3232 次
#   - 48户: 3175 次
# ----------------------------------------
# 【col: 楼栋总数】
#   - 1栋: 78373 次
#   - 2栋: 36822 次
#   - 3栋: 25672 次
#   - 4栋: 20412 次
#   - 5栋: 15426 次
# ----------------------------------------
# 【col: 物业公司】
#   - 无物业管理服务: 11009 次
#   - 业主自筹物业: 6282 次
#   - 街道办事处（居委会）代管物业: 5808 次
#   - 私人承办物业: 2122 次
#   - 小区物业: 1931 次
# ----------------------------------------
# 【col: 绿 化 率】
#   - 30%: 47345 次
#   - 35%: 27593 次
#   - 20%: 23248 次
#   - 10%: 14883 次
#   - 40%: 13593 次
# ----------------------------------------
# 【col: 容 积 率】
#   - 2.0: 28779 次
#   - 3.0: 16786 次
#   - 1.5: 12475 次
#   - 2.5: 11472 次
#   - 1.0: 11066 次
# ----------------------------------------
# 【col: 物 业 费】
#   - 0.5元/月/㎡: 21464 次
#   - 1元/月/㎡: 13911 次
#   - 1.2元/月/㎡: 10067 次
#   - 0.8元/月/㎡: 9540 次
#   - 1.5元/月/㎡: 8297 次
# ----------------------------------------
# 【col: 建筑结构】
#   - 板楼: 119530 次
#   - 塔板结合: 34985 次
#   - 塔楼: 26571 次
#   - 板楼/塔板结合: 22147 次
#   - 塔楼/板楼: 14895 次
# ----------------------------------------
# 【col: 物业办公电话】
#   - 无: 20954 次
#   - 暂无资料: 492 次
#   - 暂无: 269 次
#   - -: 259 次
#   - 022-27022093: 110 次
# ----------------------------------------
# 【col: 产权描述】
#   - 商品房: 222032 次
#   - 商品房/使用权: 12376 次
#   - 商品房/私产: 10485 次
#   - 商品房/已购公房: 9394 次
#   - 商品房/房改房: 6117 次
# ----------------------------------------
# 【col: 供水】
#   - 民水: 189994 次
#   - 商水/民水: 34414 次
#   - 商水: 6880 次
# ----------------------------------------
# 【col: 供暖】
#   - 集中供暖: 75336 次
#   - 自采暖: 49137 次
#   - 集中供暖/自采暖: 8270 次
#   - 无供暖: 918 次
#   - 自采暖/无供暖: 369 次
# ----------------------------------------
# 【col: 供电】
#   - 民电: 191088 次
#   - 商电/民电: 35674 次
#   - 商电: 6796 次
# ----------------------------------------
# 【col: 燃气费】
#   - 3元/m³: 13588 次
#   - 2.61元/m³: 10025 次
#   - 3.5元/m³: 6700 次
#   - 3.45元/m³: 6431 次
#   - 1.98元/m³: 6425 次
# ----------------------------------------
# 【col: 供热费】
#   - 25元/㎡: 8222 次
#   - 30元/㎡: 7198 次
#   - 22元/㎡: 6095 次
#   - 30.4元/㎡: 4161 次
#   - 26元/㎡: 4059 次
# ----------------------------------------
# 【col: 停车位】
#   - 100.0: 13648 次
#   - 200.0: 13076 次
#   - 50.0: 9317 次
#   - 300.0: 8328 次
#   - 20.0: 6193 次
# ----------------------------------------
# 【col: 停车费用】
#   - 150: 21294 次
#   - 300: 20479 次
#   - 200: 19364 次
#   - 100: 17829 次
#   - 暂无: 15528 次
# ----------------------------------------
# 【col: baidu_coord_x】
#   - 115.9501: 30 次
#   - 115.950135: 21 次
#   - 115.8989: 17 次
#   - 115.9101: 15 次
#   - 115.922: 13 次
# ----------------------------------------
# 【col: baidu_coord_y】
#   - 28.55: 30 次
#   - 28.550035: 21 次
#   - 28.6573: 16 次
#   - 28.6924: 15 次
#   - 28.6366: 13 次
# ----------------------------------------

# %% [markdown]
# # 2.Cleaning & Integration

# %%
# Data Cleaning

park_cleaned = park.dropna(subset=['经度','纬度'])
housing_cleaned = housing.dropna(subset=['baidu_coord_x','baidu_coord_y','参考均价','板块'])
housing_cleaned = housing_cleaned.rename(columns={'baidu_coord_x':'x','baidu_coord_y':'y','参考均价':'price'})
park_cleaned = park_cleaned.rename(columns={'经度':'x','纬度':'y'})

# %%
sub_housing = housing_cleaned.drop(columns=['环线位置','物业办公电话','供热费']).copy()
sub_park = park_cleaned[['x', 'y','产业']].copy()

# %%
# according to the distance to find the nearest park for each community
import numpy as np
from sklearn.neighbors import NearestNeighbors

park_coords_rad = np.radians(sub_park[['x', 'y']])
house_coords_rad = np.radians(sub_housing[['x', 'y']])

model = NearestNeighbors(n_neighbors=1, algorithm='ball_tree', metric='haversine')
model.fit(park_coords_rad)

distances_rad, indices = model.kneighbors(house_coords_rad)

sub_housing['nearest_park_dist_km'] = distances_rad.flatten() * 6371

sub_housing['nearest_park_index'] = sub_park.index[indices.flatten()]

sub_housing['nearest_park_industry'] = sub_park.loc[sub_housing['nearest_park_index'], '产业'].values
print(sub_housing[['x', 'y', 'nearest_park_index', 'nearest_park_dist_km']].head())
# Out:
#              x          y  nearest_park_index  nearest_park_dist_km
# 1   104.110757  30.686905               11977              0.488280
# 7   104.113817  30.696091                5638              0.170696
# 10  104.109100  30.685527               10670              0.365403
# 11  104.119772  30.693906                5646              0.530374
# 12  104.113288  30.690898                5638              0.195805

# %%
sub_housing['log_price'] = np.log(sub_housing['price'] + 1)

# %% [markdown]
# # 3.Imputation & Encoding

# %%
sub_housing.columns
# Out:
# Index(['名称', '城市', '区县', '板块', 'price', '小区地址', '物业类别', '建筑年代', '开发商', '房屋总数',
#        '楼栋总数', '物业公司', '绿 化 率', '容 积 率', '物 业 费', '建筑结构', '产权描述', '供水', '供暖',
#        '供电', '燃气费', '停车位', '停车费用', 'x', 'y', 'nearest_park_dist_km',
#        'nearest_park_index', 'nearest_park_industry', 'log_price'],
#       dtype='object')

# %%
# 城市、区县、板块 ：Embedding Encoding
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder,StandardScaler

city_le = LabelEncoder()
dist_le = LabelEncoder()
neigh_le = LabelEncoder()

sub_housing['city_idx'] = city_le.fit_transform(sub_housing['城市'])
sub_housing['dist_idx'] = dist_le.fit_transform(sub_housing['区县'])
sub_housing['neigh_idx'] = neigh_le.fit_transform(sub_housing['板块'])

n_cities = len(city_le.classes_)   
n_dists = len(dist_le.classes_)
n_neighs = len(neigh_le.classes_)

# %%
city_tensor = torch.tensor(sub_housing['city_idx'].values, dtype=torch.long)
dist_tensor = torch.tensor(sub_housing['dist_idx'].values, dtype=torch.long)
neigh_tensor = torch.tensor(sub_housing['neigh_idx'].values, dtype=torch.long)
target_tensor = torch.tensor(sub_housing['log_price'].values, dtype=torch.float32)

class GeoEmbeddingModel(nn.Module):
    def __init__(self, n_cities, n_dists, n_neighs, city_dim=8, dist_dim=24, neigh_dim=32):
        super().__init__()
        self.city_emb = nn.Embedding(n_cities, city_dim)
        self.dist_emb = nn.Embedding(n_dists, dist_dim)
        self.neigh_emb = nn.Embedding(n_neighs, neigh_dim)
        self.net = nn.Sequential(
            nn.Linear(city_dim + dist_dim + neigh_dim, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.1),
            
            nn.Linear(64, 1)
        )
        
    def forward(self, c_idx, d_idx, n_idx):
        c = self.city_emb(c_idx)
        d = self.dist_emb(d_idx)
        n = self.neigh_emb(n_idx)
        out = torch.cat([c, d, n], dim=1)
        return self.net(out)

# %%
model = GeoEmbeddingModel(n_cities, n_dists, n_neighs)
optimizer = optim.Adam(model.parameters(), lr=0.0005)
criterion = nn.MSELoss()

dataset = TensorDataset(city_tensor, dist_tensor, neigh_tensor, target_tensor)
loader = DataLoader(dataset, batch_size=256, shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import copy 


full_dataset = TensorDataset(city_tensor, dist_tensor, neigh_tensor, target_tensor)

train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False)

model = GeoEmbeddingModel(n_cities, n_dists, n_neighs)
optimizer = optim.Adam(model.parameters(), lr=0.0005)
criterion = nn.MSELoss()

epochs = 200 
patience = 10 
best_val_loss = float('inf')
counter = 0
best_model_state = None 

for epoch in range(epochs):
    
    model.train()
    train_loss = 0
    for b_city, b_dist, b_neigh, b_target in train_loader:
        optimizer.zero_grad()
        preds = model(b_city, b_dist, b_neigh)
        loss = criterion(preds, b_target.view(-1, 1)) 
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    model.eval()
    val_loss = 0
    with torch.no_grad():
        for b_city, b_dist, b_neigh, b_target in val_loader:
            preds = model(b_city, b_dist, b_neigh)
            loss = criterion(preds, b_target.view(-1, 1))
            val_loss += loss.item()
    
    avg_train_loss = train_loss / len(train_loader)
    avg_val_loss = val_loss / len(val_loader)

    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        best_model_state = copy.deepcopy(model.state_dict())
        best_epoch = epoch + 1
        counter = 0
        print(f"Epoch {epoch+1}: New best model saved! (Val Loss: {avg_val_loss:.4f})")
    else:
        counter += 1
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}: Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")
        
    if counter >= patience:
        print(f"Early stopping triggered at epoch {epoch+1}. Best Val Loss: {best_val_loss:.4f}")
        break

if best_model_state:
    model.load_state_dict(best_model_state)
    print("Successfully loaded the best model parameters.")
# Out:
# Epoch 1: New best model saved! (Val Loss: 0.7911)
# Epoch 2: New best model saved! (Val Loss: 0.4559)
# Epoch 3: New best model saved! (Val Loss: 0.3963)
# Epoch 4: New best model saved! (Val Loss: 0.3506)
# Epoch 7: New best model saved! (Val Loss: 0.3172)
# Epoch 8: New best model saved! (Val Loss: 0.3134)
# Epoch 9: New best model saved! (Val Loss: 0.2511)
# Epoch 10: New best model saved! (Val Loss: 0.2257)
# Epoch 11: New best model saved! (Val Loss: 0.1794)
# Epoch 12: New best model saved! (Val Loss: 0.1451)
# Epoch 14: New best model saved! (Val Loss: 0.1429)
# Epoch 15: New best model saved! (Val Loss: 0.1196)
# Epoch 16: New best model saved! (Val Loss: 0.1075)
# Epoch 17: New best model saved! (Val Loss: 0.1062)
# Epoch 20: Train Loss: 0.2526, Val Loss: 0.1122
# Epoch 21: New best model saved! (Val Loss: 0.0961)
# Epoch 24: New best model saved! (Val Loss: 0.0837)
# Epoch 26: New best model saved! (Val Loss: 0.0834)
# Epoch 30: Train Loss: 0.1883, Val Loss: 0.0849
# Epoch 33: New best model saved! (Val Loss: 0.0803)
# Epoch 36: New best model saved! (Val Loss: 0.0788)
# Epoch 40: Train Loss: 0.1524, Val Loss: 0.0807
# Epoch 42: New best model saved! (Val Loss: 0.0788)
# Epoch 43: New best model saved! (Val Loss: 0.0770)
# Epoch 46: New best model saved! (Val Loss: 0.0766)
# Epoch 50: Train Loss: 0.1303, Val Loss: 0.0837
# Epoch 51: New best model saved! (Val Loss: 0.0764)
# Epoch 56: New best model saved! (Val Loss: 0.0755)
# Epoch 60: Train Loss: 0.1159, Val Loss: 0.0804
# Epoch 64: New best model saved! (Val Loss: 0.0753)
# Epoch 69: New best model saved! (Val Loss: 0.0731)
# Epoch 70: Train Loss: 0.1048, Val Loss: 0.0747
# Early stopping triggered at epoch 79. Best Val Loss: 0.0731
# Successfully loaded the best model parameters.

# %%
"""
full_loader = DataLoader(full_dataset, batch_size=256, shuffle=True)

final_model = GeoEmbeddingModel(n_cities, n_dists)
final_optimizer = optim.Adam(final_model.parameters(), lr=0.0005)
final_criterion = nn.MSELoss()

final_model.train()
for epoch in range(best_epoch):
    running_loss = 0.0
    for b_city, b_dist, b_target in full_loader:
        final_optimizer.zero_grad()
        preds = final_model(b_city, b_dist)
        loss = final_criterion(preds, b_target.view(-1, 1))
        loss.backward()
        final_optimizer.step()
        running_loss += loss.item()
    
    if (epoch + 1) % 10 == 0 or (epoch + 1) == best_epoch:
        print(f"Full Training Epoch {epoch+1}/{best_epoch}, Loss: {running_loss/len(full_loader):.4f}")

with torch.no_grad():
    final_city_embeddings = final_model.city_emb.weight.detach().cpu().numpy()
    final_dist_embeddings = final_model.dist_emb.weight.detach().cpu().numpy()"""
# Out:
# '\nfull_loader = DataLoader(full_dataset, batch_size=256, shuffle=True)\n\nfinal_model = GeoEmbeddingModel(n_cities, n_dists)\nfinal_optimizer = optim.Adam(final_model.parameters(), lr=0.0005)\nfinal_criterion = nn.MSELoss()\n\nfinal_model.train()\nfor epoch in range(best_epoch):\n    running_loss = 0.0\n    for b_city, b_dist, b_target in full_loader:\n        final_optimizer.zero_grad()\n        preds = final_model(b_city, b_dist)\n        loss = final_criterion(preds, b_target.view(-1, 1))\n        loss.backward()\n        final_optimizer.step()\n        running_loss += loss.item()\n    \n    if (epoch + 1) % 10 == 0 or (epoch + 1) == best_epoch:\n        print(f"Full Training Epoch {epoch+1}/{best_epoch}, Loss: {running_loss/len(full_loader):.4f}")\n\nwith torch.no_grad():\n    final_city_embeddings = final_model.city_emb.weight.detach().cpu().numpy()\n    final_dist_embeddings = final_model.dist_emb.weight.detach().cpu().numpy()'

# %%
"""print(f"城市 Embedding 形状: {final_city_embeddings.shape}") 
print(f"区县 Embedding 形状: {final_dist_embeddings.shape}") """
# Out:
# 'print(f"城市 Embedding 形状: {final_city_embeddings.shape}") \nprint(f"区县 Embedding 形状: {final_dist_embeddings.shape}") '

# %%
city_embeddings_raw = best_model_state['city_emb.weight'].cpu().numpy()
dist_embeddings_raw = best_model_state['dist_emb.weight'].cpu().numpy()
neigh_embeddings_raw = best_model_state['neigh_emb.weight'].cpu().numpy()

print(f"城市 Embedding 形状: {city_embeddings_raw.shape}")
print(f"区县 Embedding 形状: {dist_embeddings_raw.shape}") 
print(f"板块 Embedding 形状: {neigh_embeddings_raw.shape}")
# Out:
# 城市 Embedding 形状: (89, 8)
# 区县 Embedding 形状: (911, 24)
# 板块 Embedding 形状: (4719, 32)

# %%
city_col_names = [f'city_v_{i}' for i in range(city_embeddings_raw.shape[1])]
df_city_vectors = pd.DataFrame(city_embeddings_raw, columns=city_col_names)
df_city_vectors['城市'] = city_le.classes_


dist_col_names = [f'dist_v_{i}' for i in range(dist_embeddings_raw.shape[1])]
df_dist_vectors = pd.DataFrame(dist_embeddings_raw, columns=dist_col_names)
df_dist_vectors['区县'] = dist_le.classes_

neigh_col_names = [f'neigh_v_{i}' for i in range(neigh_embeddings_raw.shape[1])]
df_neigh_vectors = pd.DataFrame(neigh_embeddings_raw, columns=neigh_col_names)
df_neigh_vectors['板块'] = neigh_le.classes_

# %%
df = sub_housing.copy()
df = df.merge(df_city_vectors, left_on='城市', right_on='城市', how='left')
df = df.merge(df_dist_vectors, left_on='区县', right_on='区县', how='left')
df = df.merge(df_neigh_vectors, left_on='板块', right_on='板块', how='left')
df.columns
# Out:
# Index(['名称', '城市', '区县', '板块', 'price', '小区地址', '物业类别', '建筑年代', '开发商', '房屋总数',
#        '楼栋总数', '物业公司', '绿 化 率', '容 积 率', '物 业 费', '建筑结构', '产权描述', '供水', '供暖',
#        '供电', '燃气费', '停车位', '停车费用', 'x', 'y', 'nearest_park_dist_km',
#        'nearest_park_index', 'nearest_park_industry', 'log_price', 'city_idx',
#        'dist_idx', 'neigh_idx', 'city_v_0', 'city_v_1', 'city_v_2', 'city_v_3',
#        'city_v_4', 'city_v_5', 'city_v_6', 'city_v_7', 'dist_v_0', 'dist_v_1',
#        'dist_v_2', 'dist_v_3', 'dist_v_4', 'dist_v_5', 'dist_v_6', 'dist_v_7',
#        'dist_v_8', 'dist_v_9', 'dist_v_10', 'dist_v_11', 'dist_v_12',
#        'dist_v_13', 'dist_v_14', 'dist_v_15', 'dist_v_16', 'dist_v_17',
#        'dist_v_18', 'dist_v_19', 'dist_v_20', 'dist_v_21', 'dist_v_22',
#        'dist_v_23', 'neigh_v_0', 'neigh_v_1', 'neigh_v_2', 'neigh_v_3',
#        'neigh_v_4', 'neigh_v_5', 'neigh_v_6', 'neigh_v_7', 'neigh_v_8',
#        'neigh_v_9', 'neigh_v_10', 'neigh_v_11', 'neigh_v_12', 'neigh_v_13',
#        'neigh_v_14', 'neigh_v_15', 'neigh_v_16', 'neigh_v_17', 'neigh_v_18',
#        'neigh_v_19', 'neigh_v_20', 'neigh_v_21', 'neigh_v_22', 'neigh_v_23',
#        'neigh_v_24', 'neigh_v_25', 'neigh_v_26', 'neigh_v_27', 'neigh_v_28',
#        'neigh_v_29', 'neigh_v_30', 'neigh_v_31'],
#       dtype='object')

# %%
# visualize the location distribution of embeddings
import umap



reducer = umap.UMAP(
    n_neighbors=2,
    min_dist=0.1,
    n_components=2,
    random_state=42
)

embedding_2d = reducer.fit_transform(dist_embeddings_raw)

dist_stats = sub_housing.groupby('区县')['log_price'].mean().reindex(dist_le.classes_)
labels = dist_stats.values

plt.figure(figsize=(10, 7))
plt.scatter(
    embedding_2d[:, 0],
    embedding_2d[:, 1],
    c=labels,         
    cmap='Spectral',
    s=10,
    alpha=0.7
)
plt.colorbar()
plt.title('UMAP Projection of High-Dimensional Embeddings')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()
# Out:
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
reducer = umap.UMAP(
    n_neighbors=2,
    min_dist=0.1,
    n_components=2,
    random_state=42
)

embedding_2d = reducer.fit_transform(city_embeddings_raw)

city_stats = sub_housing.groupby('城市')['log_price'].mean().reindex(city_le.classes_)
labels = city_stats.values

plt.figure(figsize=(10, 7))
plt.scatter(
    embedding_2d[:, 0],
    embedding_2d[:, 1],
    c=labels,         
    cmap='Spectral',
    s=10,
    alpha=0.7
)
plt.colorbar()
plt.title('UMAP Projection of High-Dimensional Embeddings')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()
# Out:
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
reducer = umap.UMAP(
    n_neighbors=2,
    min_dist=0.1,
    n_components=2,
    random_state=42
)

embedding_2d = reducer.fit_transform(neigh_embeddings_raw)

neigh_stats = sub_housing.groupby('板块')['log_price'].mean().reindex(neigh_le.classes_)
labels = neigh_stats.values

plt.figure(figsize=(10, 7))
plt.scatter(
    embedding_2d[:, 0],
    embedding_2d[:, 1],
    c=labels,         
    cmap='Spectral',
    s=10,
    alpha=0.7
)
plt.colorbar()
plt.title('UMAP Projection of High-Dimensional Embeddings')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()
# Out:
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
df.columns
# Out:
# Index(['名称', '城市', '区县', '板块', 'price', '小区地址', '物业类别', '建筑年代', '开发商', '房屋总数',
#        '楼栋总数', '物业公司', '绿 化 率', '容 积 率', '物 业 费', '建筑结构', '产权描述', '供水', '供暖',
#        '供电', '燃气费', '停车位', '停车费用', 'x', 'y', 'nearest_park_dist_km',
#        'nearest_park_index', 'nearest_park_industry', 'log_price', 'city_idx',
#        'dist_idx', 'neigh_idx', 'city_v_0', 'city_v_1', 'city_v_2', 'city_v_3',
#        'city_v_4', 'city_v_5', 'city_v_6', 'city_v_7', 'dist_v_0', 'dist_v_1',
#        'dist_v_2', 'dist_v_3', 'dist_v_4', 'dist_v_5', 'dist_v_6', 'dist_v_7',
#        'dist_v_8', 'dist_v_9', 'dist_v_10', 'dist_v_11', 'dist_v_12',
#        'dist_v_13', 'dist_v_14', 'dist_v_15', 'dist_v_16', 'dist_v_17',
#        'dist_v_18', 'dist_v_19', 'dist_v_20', 'dist_v_21', 'dist_v_22',
#        'dist_v_23', 'neigh_v_0', 'neigh_v_1', 'neigh_v_2', 'neigh_v_3',
#        'neigh_v_4', 'neigh_v_5', 'neigh_v_6', 'neigh_v_7', 'neigh_v_8',
#        'neigh_v_9', 'neigh_v_10', 'neigh_v_11', 'neigh_v_12', 'neigh_v_13',
#        'neigh_v_14', 'neigh_v_15', 'neigh_v_16', 'neigh_v_17', 'neigh_v_18',
#        'neigh_v_19', 'neigh_v_20', 'neigh_v_21', 'neigh_v_22', 'neigh_v_23',
#        'neigh_v_24', 'neigh_v_25', 'neigh_v_26', 'neigh_v_27', 'neigh_v_28',
#        'neigh_v_29', 'neigh_v_30', 'neigh_v_31'],
#       dtype='object')

# %% [markdown]
# ### Numerical variables

# %%
import re
def process_price(text):

    if pd.isna(text):
        return None
    nums = re.findall(r"\d+\.?\d*", text)
    nums = [float(n) for n in nums]

    if len(nums) >= 2:
        avg = sum(nums[:2]) / 2
        return avg
    elif len(nums) == 1:
        return nums[0]
    else:
        return None
    
def extract_year(text):
    if pd.isna(text):
        return None
    match = re.search(r'(\d{4})', str(text))
    if match:
        return int(match.group(1))
    return None

# %%
df['房屋总数'] = df['房屋总数'].apply(process_price)
df['楼栋总数'] = df['楼栋总数'].apply(process_price)
df['绿 化 率'] = df['绿 化 率'].apply(process_price)

# %%
df['燃气费'] = df['燃气费'].apply(process_price)
df['物 业 费'] = df['物 业 费'].apply(process_price)
df['建筑年代'] = df['建筑年代'].apply(extract_year)

# %% [markdown]
# ### Catagorical Encoding

# %%
base_types = ['板楼', '塔楼', '塔板结合', '平房']

for t in base_types:
    df[f'{t}'] = df['建筑结构'].str.contains(t, na=False).astype(int)

df['structure_missing'] = df['建筑结构'].isna().astype(int)

# %%
col_name = '物业类别'

unique_types = (
    df[col_name]
    .dropna()
    .str.split('/')
    .explode()
    .str.strip()  
    .unique()
)

print(f"检测到的基础物业类型共有 {len(unique_types)} 种：")
print(unique_types)

for t in unique_types:
    df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)

df['property_type_missing'] = df[col_name].isna().astype(int)
# Out:
# 检测到的基础物业类型共有 25 种：
# ['普通住宅' '底商' '车库' '商业' '写字楼' '商业办公类' '公寓' '别墅' '商住两用' '四合院' '人防车位' '平房'
#  '公寓（住宅）' '工业厂房' '酒店式公寓' '地下仓储' '库房' '住宅' '单身公寓（住宅）' '商务型公寓' '住宅式公寓'
#  '服务式公寓' '新式里弄' '花园洋房' '商务公寓']

# %%
col_name = '产权描述'

unique_types = (
    df[col_name]
    .dropna()
    .str.split('/')
    .explode()
    .str.strip()  
    .unique()
)

for t in unique_types:
    df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)

df['right_missing'] = df[col_name].isna().astype(int)

# %%
col_name = '供水'

unique_types = (
    df[col_name]
    .dropna()
    .str.split('/')
    .explode()
    .str.strip()  
    .unique()
)

for t in unique_types:
    df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)

df['water_missing'] = df[col_name].isna().astype(int)

# %%
col_name = '供电'

unique_types = (
    df[col_name]
    .dropna()
    .str.split('/')
    .explode()
    .str.strip()  
    .unique()
)

for t in unique_types:
    df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)

df['power_missing'] = df[col_name].isna().astype(int)

# %%
col_name = '供暖'

unique_types = (
    df[col_name]
    .dropna()
    .str.split('/')
    .explode()
    .str.strip()  
    .unique()
)

for t in unique_types:
    df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)

df['heating_missing'] = df[col_name].isna().astype(int)

# %%
col_name = 'nearest_park_industry'

unique_types = (
    df[col_name]
    .dropna()
    .str.split('/')
    .explode()
    .str.strip()  
    .unique()
)

for t in unique_types:
    df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# Out:
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)
# /tmp/ipykernel_3517082/954184528.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'is_{t}'] = df[col_name].str.contains(t, na=False, regex=False).astype(int)

# %%
stat = df.drop(columns=['名称', '城市', '区县', '板块', '小区地址','开发商','物业公司','停车费用','物业类别','建筑结构','产权描述','供水','供电','供暖','nearest_park_industry'])

# %%
# display the all columns after processing
print(stat.columns.tolist())
print(len(stat.columns))
# Out:
# ['price', '建筑年代', '房屋总数', '楼栋总数', '绿 化 率', '容 积 率', '物 业 费', '燃气费', '停车位', 'x', 'y', 'nearest_park_dist_km', 'nearest_park_index', 'log_price', 'city_idx', 'dist_idx', 'neigh_idx', 'city_v_0', 'city_v_1', 'city_v_2', 'city_v_3', 'city_v_4', 'city_v_5', 'city_v_6', 'city_v_7', 'dist_v_0', 'dist_v_1', 'dist_v_2', 'dist_v_3', 'dist_v_4', 'dist_v_5', 'dist_v_6', 'dist_v_7', 'dist_v_8', 'dist_v_9', 'dist_v_10', 'dist_v_11', 'dist_v_12', 'dist_v_13', 'dist_v_14', 'dist_v_15', 'dist_v_16', 'dist_v_17', 'dist_v_18', 'dist_v_19', 'dist_v_20', 'dist_v_21', 'dist_v_22', 'dist_v_23', 'neigh_v_0', 'neigh_v_1', 'neigh_v_2', 'neigh_v_3', 'neigh_v_4', 'neigh_v_5', 'neigh_v_6', 'neigh_v_7', 'neigh_v_8', 'neigh_v_9', 'neigh_v_10', 'neigh_v_11', 'neigh_v_12', 'neigh_v_13', 'neigh_v_14', 'neigh_v_15', 'neigh_v_16', 'neigh_v_17', 'neigh_v_18', 'neigh_v_19', 'neigh_v_20', 'neigh_v_21', 'neigh_v_22', 'neigh_v_23', 'neigh_v_24', 'neigh_v_25', 'neigh_v_26', 'neigh_v_27', 'neigh_v_28', 'neigh_v_29', 'neigh_v_30', 'neigh_v_31', '板楼', '塔楼', '塔板结合', '平房', 'structure_missing', 'is_普通住宅', 'is_底商', 'is_车库', 'is_商业', 'is_写字楼', 'is_商业办公类', 'is_公寓', 'is_别墅', 'is_商住两用', 'is_四合院', 'is_人防车位', 'is_平房', 'is_公寓（住宅）', 'is_工业厂房', 'is_酒店式公寓', 'is_地下仓储', 'is_库房', 'is_住宅', 'is_单身公寓（住宅）', 'is_商务型公寓', 'is_住宅式公寓', 'is_服务式公寓', 'is_新式里弄', 'is_花园洋房', 'is_商务公寓', 'property_type_missing', 'is_商品房', 'is_拆迁安置房', 'is_使用权', 'is_经济适用房', 'is_私产', 'is_公租房', 'is_已购公房', 'is_限价商品房', 'is_共有产权房', 'is_自建房', 'is_集资房', 'is_军产', 'is_乡产', 'is_新居工程房', 'is_廉租房', 'is_平价房', 'is_校产', 'is_回迁房', 'is_宗教产', 'is_房改房', 'is_一类经济适用房', 'is_二类经济适用房', 'is_定向安置房', 'is_央产房', 'is_自住型商品房', 'is_售后公房', 'is_动迁安置房', 'is_人才专用房', 'is_经济解困房', 'is_企业产', 'is_公产房', 'is_拆迁还建房', 'is_人才公寓', 'is_地产房', 'is_康居安置房', 'is_保障性住房', 'is_宅基房', 'is_安居型商品房', 'right_missing', 'is_商水', 'is_民水', 'water_missing', 'is_商电', 'is_民电', 'power_missing', 'is_自采暖', 'is_无供暖', 'is_集中供暖', 'heating_missing', 'is_文化创意', 'is_其他', 'is_房地产建筑', 'is_家电数码', 'is_电子信息', 'is_纺织服装', 'is_农林牧渔', 'is_大消费', 'is_机械设备', 'is_高新技术', 'is_仓储物流', 'is_化工日化', 'is_航空航天', 'is_电子商务', 'is_轻工业', 'is_装备制造', 'is_医疗医药', 'is_国防科技产业', 'is_建材冶金', 'is_电子产业', 'is_汽车工业', 'is_食品饮料', 'is_能源电力', 'is_环保节能', 'is_科技服务', 'is_金融保险']
# 187

# %%
# summary statistics of the columns
stat.describe()
# Out:
#                price           建筑年代           房屋总数           楼栋总数  \
# count  238564.000000  156828.000000  238534.000000  238530.000000
# mean    16987.984017    2000.163236     603.754182      10.938448
# std     18396.164476      10.815694     916.620661      21.905455
# min      1824.000000    1900.000000       1.000000       1.000000
# 25%      7555.000000    1995.000000      84.000000       2.000000
# 50%     11079.000000    2000.000000     279.000000       5.000000
# 75%     18064.250000    2007.000000     767.000000      12.000000
# max    300807.000000    2085.000000   29676.000000    1377.000000
#
#                绿 化 率          容 积 率          物 业 费            燃气费  \
# count  170298.000000  171987.000000  167860.000000  167261.000000
# mean       34.395159      10.674745       1.804400       2.694985
# std      1317.284139    2230.878437      13.495554       1.142785
# min         0.010000       0.010000       0.001000       0.010000
# 25%        20.000000       1.600000       0.600000       2.300000
# 50%        30.000000       2.100000       1.110000       2.610000
# 75%        35.000000       3.000000       1.875000       3.100000
# max    400000.000000  896481.000000    5000.250000     174.225000
#
#                 停车位              x  ...        is_医疗医药      is_国防科技产业  \
# count  1.571610e+05  238564.000000  ...  238564.000000  238564.000000
# mean   6.340331e+02     114.911255  ...       0.003123       0.000163
# std    2.525616e+04       5.648457  ...       0.055795       0.012785
# min    1.000000e+00     102.201741  ...       0.000000       0.000000
# 25%    1.000000e+02     112.256793  ...       0.000000       0.000000
# 50%    2.500000e+02     115.090024  ...       0.000000       0.000000
# 75%    6.480000e+02     119.321764  ...       0.000000       0.000000
# max    1.000100e+07     129.577872  ...       1.000000       1.000000
#
#              is_建材冶金        is_电子产业        is_汽车工业        is_食品饮料  \
# count  238564.000000  238564.000000  238564.000000  238564.000000
# mean        0.015656       0.002264       0.002058       0.001014
# std         0.124142       0.047523       0.045320       0.031834
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#              is_能源电力        is_环保节能        is_科技服务        is_金融保险
# count  238564.000000  238564.000000  238564.000000  238564.000000
# mean        0.004519       0.005143       0.001258       0.001006
# std         0.067069       0.071532       0.035439       0.031702
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 187 columns]

# %% [markdown]
# # 3.Model building

# %%
from my_xgboost import XGBGPUTrainer
from sklearn.model_selection import train_test_split

X = stat.drop(columns=['log_price','price'])
y = stat['log_price']

np.expm1

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

params = {
    'n_estimators': 5000,
    'learning_rate': 0.01,
    'max_depth': 9,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'tree_method': 'hist',
    'device': 'cuda',
    'early_stopping_rounds': 50
}
trainer = XGBGPUTrainer(params)
trainer.train(X_train, y_train, X_test, y_test)

metrics, final_preds = trainer.evaluate(X_test, y_test, inverse_func=np.expm1)

print(f"Test Metrics: {metrics}")
# Out:
# [0]	validation_0-rmse:0.71614	validation_1-rmse:0.71676
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/xgboost/callback.py:386: UserWarning: [16:48:05] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1768314083701/work/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   self.starting_round = model.num_boosted_rounds()
# [100]	validation_0-rmse:0.37723	validation_1-rmse:0.38089
# [200]	validation_0-rmse:0.27215	validation_1-rmse:0.27956
# [300]	validation_0-rmse:0.23810	validation_1-rmse:0.24918
# [400]	validation_0-rmse:0.22151	validation_1-rmse:0.23608
# [500]	validation_0-rmse:0.21196	validation_1-rmse:0.22943
# [600]	validation_0-rmse:0.20525	validation_1-rmse:0.22504
# [700]	validation_0-rmse:0.20047	validation_1-rmse:0.22226
# [800]	validation_0-rmse:0.19661	validation_1-rmse:0.22015
# [900]	validation_0-rmse:0.19330	validation_1-rmse:0.21846
# [1000]	validation_0-rmse:0.19036	validation_1-rmse:0.21713
# [1100]	validation_0-rmse:0.18763	validation_1-rmse:0.21593
# [1200]	validation_0-rmse:0.18529	validation_1-rmse:0.21494
# [1300]	validation_0-rmse:0.18307	validation_1-rmse:0.21412
# [1400]	validation_0-rmse:0.18079	validation_1-rmse:0.21333
# [1500]	validation_0-rmse:0.17878	validation_1-rmse:0.21259
# [1600]	validation_0-rmse:0.17680	validation_1-rmse:0.21192
# [1700]	validation_0-rmse:0.17501	validation_1-rmse:0.21130
# [1800]	validation_0-rmse:0.17319	validation_1-rmse:0.21074
# [1900]	validation_0-rmse:0.17131	validation_1-rmse:0.21019
# [2000]	validation_0-rmse:0.16968	validation_1-rmse:0.20970
# [2100]	validation_0-rmse:0.16806	validation_1-rmse:0.20926
# [2200]	validation_0-rmse:0.16642	validation_1-rmse:0.20883
# [2300]	validation_0-rmse:0.16490	validation_1-rmse:0.20844
# [2400]	validation_0-rmse:0.16332	validation_1-rmse:0.20809
# [2500]	validation_0-rmse:0.16172	validation_1-rmse:0.20771
# [2600]	validation_0-rmse:0.16026	validation_1-rmse:0.20739
# [2700]	validation_0-rmse:0.15877	validation_1-rmse:0.20705
# [2800]	validation_0-rmse:0.15738	validation_1-rmse:0.20676
# [2900]	validation_0-rmse:0.15592	validation_1-rmse:0.20649
# [3000]	validation_0-rmse:0.15453	validation_1-rmse:0.20622
# [3100]	validation_0-rmse:0.15308	validation_1-rmse:0.20592
# [3200]	validation_0-rmse:0.15169	validation_1-rmse:0.20567
# [3300]	validation_0-rmse:0.15037	validation_1-rmse:0.20544
# [3400]	validation_0-rmse:0.14902	validation_1-rmse:0.20523
# [3500]	validation_0-rmse:0.14770	validation_1-rmse:0.20503
# [3600]	validation_0-rmse:0.14638	validation_1-rmse:0.20484
# [3700]	validation_0-rmse:0.14513	validation_1-rmse:0.20467
# [3800]	validation_0-rmse:0.14389	validation_1-rmse:0.20449
# [3900]	validation_0-rmse:0.14267	validation_1-rmse:0.20434
# [4000]	validation_0-rmse:0.14145	validation_1-rmse:0.20416
# [4100]	validation_0-rmse:0.14026	validation_1-rmse:0.20402
# [4200]	validation_0-rmse:0.13902	validation_1-rmse:0.20389
# [4300]	validation_0-rmse:0.13784	validation_1-rmse:0.20377
# [4400]	validation_0-rmse:0.13666	validation_1-rmse:0.20364
# [4500]	validation_0-rmse:0.13552	validation_1-rmse:0.20353
# [4600]	validation_0-rmse:0.13445	validation_1-rmse:0.20342
# [4700]	validation_0-rmse:0.13335	validation_1-rmse:0.20331
# [4800]	validation_0-rmse:0.13227	validation_1-rmse:0.20321
# [4900]	validation_0-rmse:0.13128	validation_1-rmse:0.20312
# [4999]	validation_0-rmse:0.13017	validation_1-rmse:0.20303
#
# --- 评估结果 (已转换回原始尺度) ---
# RMSE: 4963.9332
# MAE: 2420.3732
# R2: 0.9263
# Test Metrics: {'RMSE': 4963.933167010625, 'MAE': 2420.373177001805, 'R2': 0.9263099040281775}

# %% [markdown]
# # 4.Sensitivity

# %%
import shap
import matplotlib.pyplot as plt
from sklearn.inspection import PartialDependenceDisplay

y_pred = trainer.predict(X_test)

print("正在计算 SHAP 值...")

def model_predict(data):
    return trainer.model.predict(data)

masker = shap.maskers.Independent(data=X_train)
explainer = shap.Explainer(model_predict, masker)

X_test_sample = X_test.head(200) 
shap_values = explainer(X_test_sample)
# Out:
# 正在计算 SHAP 值...
# PermutationExplainer explainer: 201it [00:42,  3.59it/s]

# %%
import matplotlib.font_manager as fm

# 打印出你系统中所有可用的中文字体名称
for font in fm.fontManager.ttflist:
    # 常见的中文名称关键词
    if any(x in font.name.lower() for x in ['hei', 'song', 'unicode', 'chinese', 'kai']):
        print(f"字体名: {font.name} --- 路径: {font.fname}")
# Out:
# 字体名: STIXNonUnicode --- 路径: /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf
# 字体名: STIXNonUnicode --- 路径: /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf
# 字体名: STIXNonUnicode --- 路径: /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf
# 字体名: STIXNonUnicode --- 路径: /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf
# 字体名: Noto Sans Kaithi --- 路径: /usr/share/fonts/truetype/noto/NotoSansKaithi-Regular.ttf

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']  
plt.rcParams['axes.unicode_minus'] = False  

plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_sample)
plt.show()

plt.figure(figsize=(12, 5))
shap.plots.waterfall(shap_values[0])
plt.show()

shap.plots.scatter(shap_values[:, "nearest_park_dist_km"])
# Out:
# /tmp/ipykernel_3517082/3607603651.py:5: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_test_sample)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 29123 (\N{CJK UNIFIED IDEOGRAPH-71C3}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 27668 (\N{CJK UNIFIED IDEOGRAPH-6C14}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 36153 (\N{CJK UNIFIED IDEOGRAPH-8D39}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 32511 (\N{CJK UNIFIED IDEOGRAPH-7EFF}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 25151 (\N{CJK UNIFIED IDEOGRAPH-623F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 23627 (\N{CJK UNIFIED IDEOGRAPH-5C4B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 24635 (\N{CJK UNIFIED IDEOGRAPH-603B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 27004 (\N{CJK UNIFIED IDEOGRAPH-697C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 26635 (\N{CJK UNIFIED IDEOGRAPH-680B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 24314 (\N{CJK UNIFIED IDEOGRAPH-5EFA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 31569 (\N{CJK UNIFIED IDEOGRAPH-7B51}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 20195 (\N{CJK UNIFIED IDEOGRAPH-4EE3}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 29289 (\N{CJK UNIFIED IDEOGRAPH-7269}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/shap/plots/_beeswarm.py:1150: UserWarning: Glyph 19994 (\N{CJK UNIFIED IDEOGRAPH-4E1A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 29123 (\N{CJK UNIFIED IDEOGRAPH-71C3}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27668 (\N{CJK UNIFIED IDEOGRAPH-6C14}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 36153 (\N{CJK UNIFIED IDEOGRAPH-8D39}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 32511 (\N{CJK UNIFIED IDEOGRAPH-7EFF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25151 (\N{CJK UNIFIED IDEOGRAPH-623F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23627 (\N{CJK UNIFIED IDEOGRAPH-5C4B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24635 (\N{CJK UNIFIED IDEOGRAPH-603B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27004 (\N{CJK UNIFIED IDEOGRAPH-697C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26635 (\N{CJK UNIFIED IDEOGRAPH-680B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24314 (\N{CJK UNIFIED IDEOGRAPH-5EFA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 31569 (\N{CJK UNIFIED IDEOGRAPH-7B51}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20195 (\N{CJK UNIFIED IDEOGRAPH-4EE3}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 29289 (\N{CJK UNIFIED IDEOGRAPH-7269}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 19994 (\N{CJK UNIFIED IDEOGRAPH-4E1A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25151 (\N{CJK UNIFIED IDEOGRAPH-623F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23627 (\N{CJK UNIFIED IDEOGRAPH-5C4B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24635 (\N{CJK UNIFIED IDEOGRAPH-603B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
print("正在生成 PDP 图...")

plt.rcParams['font.sans-serif'] = ['SimHei']  
plt.rcParams['axes.unicode_minus'] = False  

important_features = X_train.columns[:3].tolist() 

fig, ax = plt.subplots(figsize=(15, 5))
PartialDependenceDisplay.from_estimator(
    trainer.model, 
    X_train, 
    features=important_features, 
    ax=ax,
    grid_resolution=50 
)
plt.suptitle("PDP Analysis of Key Features")
plt.tight_layout()
plt.show()
# Out:
# 正在生成 PDP 图...
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 24314 (\N{CJK UNIFIED IDEOGRAPH-5EFA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 31569 (\N{CJK UNIFIED IDEOGRAPH-7B51}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 20195 (\N{CJK UNIFIED IDEOGRAPH-4EE3}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 25151 (\N{CJK UNIFIED IDEOGRAPH-623F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 23627 (\N{CJK UNIFIED IDEOGRAPH-5C4B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 24635 (\N{CJK UNIFIED IDEOGRAPH-603B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 27004 (\N{CJK UNIFIED IDEOGRAPH-697C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_3517082/2746080756.py:17: UserWarning: Glyph 26635 (\N{CJK UNIFIED IDEOGRAPH-680B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24314 (\N{CJK UNIFIED IDEOGRAPH-5EFA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 31569 (\N{CJK UNIFIED IDEOGRAPH-7B51}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20195 (\N{CJK UNIFIED IDEOGRAPH-4EE3}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25151 (\N{CJK UNIFIED IDEOGRAPH-623F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23627 (\N{CJK UNIFIED IDEOGRAPH-5C4B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24635 (\N{CJK UNIFIED IDEOGRAPH-603B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27004 (\N{CJK UNIFIED IDEOGRAPH-697C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yubo/.conda/envs/Housing/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26635 (\N{CJK UNIFIED IDEOGRAPH-680B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
print("正在生成 km 的 PDP 图...")

fig, ax = plt.subplots(figsize=(8, 6))

PartialDependenceDisplay.from_estimator(
    trainer.model, 
    X_train, 
    features=['nearest_park_dist_km'], 
    ax=ax,
    grid_resolution=50
)

plt.title("Partial Dependence of nearest_park_dist_km")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# 正在生成 km 的 PDP 图...
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
