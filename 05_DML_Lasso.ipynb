# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV
import warnings
warnings.filterwarnings('ignore')

# %%
city = '北京'

# %%
housing = pd.read_csv(f'processed_data/{city}/03_data.csv')

# %%
print(housing.columns.tolist())
# Out:
# ['城市', '区域', '板块', 'price', 'unit_price', '配备电梯', '挂牌时间', '上次交易', '产权所属', '核心卖点', '户型介绍', '周边配套', '交通出行', 'x', 'y', '年份', 'nearest_park_dist_km', 'nearest_park_index', 'nearest_park_industry', 'log_price', 'log_unit_price', 'area', 'distance_to_center', 'rooms', 'halls', 'kitchens', 'bathrooms', '看房时间_is_只周末可看', '看房时间_is_下班后可看', '看房时间_is_提前预约随时可看', '看房时间_is_有租户需预约', 'total_floors', 'floor_level_is_低楼层', 'floor_level_is_底层', 'floor_level_is_高楼层', 'floor_level_is_中楼层', 'floor_level_is_顶层', 'floor_level_is_地下室', '房屋朝向_is_南', '房屋朝向_is_北', '房屋朝向_is_东', '房屋朝向_is_西', '房屋朝向_is_西北', '房屋朝向_is_西南', '房屋朝向_is_东南', '房屋朝向_is_东北', '建筑结构_is_钢混结构', '建筑结构_is_混合结构', '建筑结构_is_未知结构', '建筑结构_is_砖混结构', '建筑结构_is_钢结构', '建筑结构_is_砖木结构', '建筑结构_is_框架结构', '装修情况_is_精装', '装修情况_is_简装', '装修情况_is_毛坯', '装修情况_is_其它', '装修情况_is_其他', 'elevators', 'households', 'elevators_household_ratio', '别墅类型_is_非别墅', '别墅类型_is_独栋', '别墅类型_is_联排', '别墅类型_is_叠拼', '别墅类型_is_双拼', '交易权属_is_私产', '交易权属_is_商品房', '交易权属_is_已购公房', '交易权属_is_一类经济适用房', '交易权属_is_二类经济适用房', '交易权属_is_央产房', '交易权属_is_限价商品房', '交易权属_is_定向安置房', '交易权属_is_自住型商品房', '房屋用途_is_普通住宅', '房屋用途_is_别墅', '房屋用途_is_车库', '房屋用途_is_商业办公类', '房屋用途_is_公寓', '房屋用途_is_住宅', '房屋用途_is_酒店式公寓', '房屋用途_is_平房', '房屋用途_is_商务型公寓', '房屋用途_is_公寓（住宅）', '房屋用途_is_服务式公寓', '房屋用途_is_四合院', '房屋用途_is_住宅式公寓', '房屋用途_is_单身公寓（住宅）', '房屋年限_is_满五年', '房屋年限_is_满两年', '房屋年限_is_未满两年', '房源标签_is_VR看装修', '房源标签_is_房本满五年', '房源标签_is_VR房源', '房源标签_is_地铁', '房源标签_is_随时看房', '房源标签_is_房本满两年', 'category_is_Others', 'category_is_High-Tech', 'category_is_General-Mfg', 'category_is_Heavy-Nuisance', 'category_is_Modern-Service']

# %%
stats = housing.drop(columns=['城市', '区域', '板块', '挂牌时间', '上次交易', '核心卖点', '户型介绍', '周边配套', '交通出行'
                              ,'nearest_park_index','nearest_park_industry','年份','x','y'])

# %%
from utils import Display
Display(stats)
# Out:
# Shape: (261159, 89)
# Index(['price', 'unit_price', '配备电梯', '产权所属', 'nearest_park_dist_km',
#        'log_price', 'log_unit_price', 'area', 'distance_to_center', 'rooms',
#        'halls', 'kitchens', 'bathrooms', '看房时间_is_只周末可看', '看房时间_is_下班后可看',
#        '看房时间_is_提前预约随时可看', '看房时间_is_有租户需预约', 'total_floors',
#        'floor_level_is_低楼层', 'floor_level_is_底层', 'floor_level_is_高楼层',
#        'floor_level_is_中楼层', 'floor_level_is_顶层', 'floor_level_is_地下室',
#        '房屋朝向_is_南', '房屋朝向_is_北', '房屋朝向_is_东', '房屋朝向_is_西', '房屋朝向_is_西北',
#        '房屋朝向_is_西南', '房屋朝向_is_东南', '房屋朝向_is_东北', '建筑结构_is_钢混结构',
#        '建筑结构_is_混合结构', '建筑结构_is_未知结构', '建筑结构_is_砖混结构', '建筑结构_is_钢结构',
#        '建筑结构_is_砖木结构', '建筑结构_is_框架结构', '装修情况_is_精装', '装修情况_is_简装',
#        '装修情况_is_毛坯', '装修情况_is_其它', '装修情况_is_其他', 'elevators', 'households',
#        'elevators_household_ratio', '别墅类型_is_非别墅', '别墅类型_is_独栋', '别墅类型_is_联排',
#        '别墅类型_is_叠拼', '别墅类型_is_双拼', '交易权属_is_私产', '交易权属_is_商品房', '交易权属_is_已购公房',
#        '交易权属_is_一类经济适用房', '交易权属_is_二类经济适用房', '交易权属_is_央产房', '交易权属_is_限价商品房',
#        '交易权属_is_定向安置房', '交易权属_is_自住型商品房', '房屋用途_is_普通住宅', '房屋用途_is_别墅',
#        '房屋用途_is_车库', '房屋用途_is_商业办公类', '房屋用途_is_公寓', '房屋用途_is_住宅',
#        '房屋用途_is_酒店式公寓', '房屋用途_is_平房', '房屋用途_is_商务型公寓', '房屋用途_is_公寓（住宅）',
#        '房屋用途_is_服务式公寓', '房屋用途_is_四合院', '房屋用途_is_住宅式公寓', '房屋用途_is_单身公寓（住宅）',
#        '房屋年限_is_满五年', '房屋年限_is_满两年', '房屋年限_is_未满两年', '房源标签_is_VR看装修',
#        '房源标签_is_房本满五年', '房源标签_is_VR房源', '房源标签_is_地铁', '房源标签_is_随时看房',
#        '房源标签_is_房本满两年', 'category_is_Others', 'category_is_High-Tech',
#        'category_is_General-Mfg', 'category_is_Heavy-Nuisance',
#        'category_is_Modern-Service'],
#       dtype='object')
#                             Missing  Unique    Dtype
# price                             0    2818  float64
# unit_price                        0   99366  float64
# 配备电梯                              0       2    int64
# 产权所属                              0       2    int64
# nearest_park_dist_km              0    8277  float64
# ...                             ...     ...      ...
# category_is_Others                0       2    int64
# category_is_High-Tech             0       2    int64
# category_is_General-Mfg           0       2    int64
# category_is_Heavy-Nuisance        0       2    int64
# category_is_Modern-Service        0       2    int64
#
# [89 rows x 3 columns]
# 【col: price】
#   - 450.0: 1974 次
#   - 550.0: 1686 次
#   - 420.0: 1667 次
#   - 320.0: 1663 次
#   - 330.0: 1647 次
# ----------------------------------------
# 【col: unit_price】
#   - 100000.0: 112 次
#   - 50000.0: 43 次
#   - 125000.0: 41 次
#   - 45455.0: 39 次
#   - 62500.0: 37 次
# ----------------------------------------
# 【col: 配备电梯】
#   - 1: 148836 次
#   - 0: 112323 次
# ----------------------------------------
# 【col: 产权所属】
#   - 2: 228758 次
#   - 1: 32401 次
# ----------------------------------------
# 【col: nearest_park_dist_km】
#   - 1.0558044660826411: 531 次
#   - 0.1682971198726757: 527 次
#   - 0.2633951853487862: 523 次
#   - 12.279585246760934: 517 次
#   - 1.251156431953514: 494 次
# ----------------------------------------
# 【col: log_price】
#   - 6.1092475827643655: 1974 次
#   - 6.309918278226516: 1686 次
#   - 6.040254711277414: 1667 次
#   - 5.768320995793772: 1663 次
#   - 5.799092654460526: 1647 次
# ----------------------------------------
# 【col: log_unit_price】
#   - 11.512925464970229: 112 次
#   - 10.819778284410283: 43 次
#   - 11.736069016284436: 41 次
#   - 10.724478104555958: 39 次
#   - 11.042921835724492: 37 次
# ----------------------------------------
# 【col: area】
#   - 62.5: 94 次
#   - 50.0: 93 次
#   - 61.19951040391677: 64 次
#   - 80.0: 57 次
#   - 60.0: 55 次
# ----------------------------------------
# 【col: distance_to_center】
#   - 15.59279182902118: 531 次
#   - 8.357740472456419: 527 次
#   - 14.303603209915586: 523 次
#   - 108.00418093690791: 517 次
#   - 5.55976242416721: 494 次
# ----------------------------------------
# 【col: rooms】
#   - 2: 117192 次
#   - 3: 60124 次
#   - 1: 40935 次
#   - 0: 26973 次
#   - 4: 10916 次
# ----------------------------------------
# 【col: halls】
#   - 1: 175417 次
#   - 2: 48951 次
#   - 0: 34072 次
#   - 3: 2355 次
#   - 4: 273 次
# ----------------------------------------
# 【col: kitchens】
#   - 1: 232060 次
#   - 0: 27826 次
#   - 2: 1242 次
#   - 3: 24 次
#   - 4: 6 次
# ----------------------------------------
# 【col: bathrooms】
#   - 1: 183644 次
#   - 2: 47748 次
#   - 0: 19378 次
#   - 3: 6921 次
#   - 4: 2304 次
# ----------------------------------------
# 【col: 看房时间_is_只周末可看】
#   - 0: 252250 次
#   - 1: 8909 次
# ----------------------------------------
# 【col: 看房时间_is_下班后可看】
#   - 0: 247713 次
#   - 1: 13446 次
# ----------------------------------------
# 【col: 看房时间_is_提前预约随时可看】
#   - 1: 182031 次
#   - 0: 79128 次
# ----------------------------------------
# 【col: 看房时间_is_有租户需预约】
#   - 0: 204386 次
#   - 1: 56773 次
# ----------------------------------------
# 【col: total_floors】
#   - 6.0: 75422 次
#   - 0.0: 17225 次
#   - 18.0: 15957 次
#   - 5.0: 12643 次
#   - 7.0: 10068 次
# ----------------------------------------
# 【col: floor_level_is_低楼层】
#   - 0: 212792 次
#   - 1: 48367 次
# ----------------------------------------
# 【col: floor_level_is_底层】
#   - 0: 234675 次
#   - 1: 26484 次
# ----------------------------------------
# 【col: floor_level_is_高楼层】
#   - 0: 211592 次
#   - 1: 49567 次
# ----------------------------------------
# 【col: floor_level_is_中楼层】
#   - 0: 176465 次
#   - 1: 84694 次
# ----------------------------------------
# 【col: floor_level_is_顶层】
#   - 0: 229000 次
#   - 1: 32159 次
# ----------------------------------------
# 【col: floor_level_is_地下室】
#   - 0: 258059 次
#   - 1: 3100 次
# ----------------------------------------
# 【col: 房屋朝向_is_南】
#   - 1: 197324 次
#   - 0: 63835 次
# ----------------------------------------
# 【col: 房屋朝向_is_北】
#   - 1: 150325 次
#   - 0: 110834 次
# ----------------------------------------
# 【col: 房屋朝向_is_东】
#   - 0: 212382 次
#   - 1: 48777 次
# ----------------------------------------
# 【col: 房屋朝向_is_西】
#   - 0: 215911 次
#   - 1: 45248 次
# ----------------------------------------
# 【col: 房屋朝向_is_西北】
#   - 0: 255423 次
#   - 1: 5736 次
# ----------------------------------------
# 【col: 房屋朝向_is_西南】
#   - 0: 248912 次
#   - 1: 12247 次
# ----------------------------------------
# 【col: 房屋朝向_is_东南】
#   - 0: 247626 次
#   - 1: 13533 次
# ----------------------------------------
# 【col: 房屋朝向_is_东北】
#   - 0: 256253 次
#   - 1: 4906 次
# ----------------------------------------
# 【col: 建筑结构_is_钢混结构】
#   - 1: 149331 次
#   - 0: 111828 次
# ----------------------------------------
# 【col: 建筑结构_is_混合结构】
#   - 0: 170790 次
#   - 1: 90369 次
# ----------------------------------------
# 【col: 建筑结构_is_未知结构】
#   - 0: 242264 次
#   - 1: 18895 次
# ----------------------------------------
# 【col: 建筑结构_is_砖混结构】
#   - 0: 259002 次
#   - 1: 2157 次
# ----------------------------------------
# 【col: 建筑结构_is_钢结构】
#   - 0: 260961 次
#   - 1: 198 次
# ----------------------------------------
# 【col: 建筑结构_is_砖木结构】
#   - 0: 260983 次
#   - 1: 176 次
# ----------------------------------------
# 【col: 建筑结构_is_框架结构】
#   - 0: 261126 次
#   - 1: 33 次
# ----------------------------------------
# 【col: 装修情况_is_精装】
#   - 0: 151161 次
#   - 1: 109998 次
# ----------------------------------------
# 【col: 装修情况_is_简装】
#   - 0: 177050 次
#   - 1: 84109 次
# ----------------------------------------
# 【col: 装修情况_is_毛坯】
#   - 0: 256598 次
#   - 1: 4561 次
# ----------------------------------------
# 【col: 装修情况_is_其它】
#   - 0: 242586 次
#   - 1: 18573 次
# ----------------------------------------
# 【col: 装修情况_is_其他】
#   - 0: 217241 次
#   - 1: 43918 次
# ----------------------------------------
# 【col: elevators】
#   - 1: 138103 次
#   - 2: 73835 次
#   - 0: 19988 次
#   - 3: 18453 次
#   - 4: 7176 次
# ----------------------------------------
# 【col: households】
#   - 2: 82898 次
#   - 3: 46441 次
#   - 4: 30785 次
#   - 0: 19988 次
#   - 8: 15252 次
# ----------------------------------------
# 【col: elevators_household_ratio】
#   - 0.5: 95521 次
#   - 0.3333333333333333: 48271 次
#   - 0.25: 26473 次
#   - 0.0: 19988 次
#   - 1.0: 9696 次
# ----------------------------------------
# 【col: 别墅类型_is_非别墅】
#   - 1: 260732 次
#   - 0: 427 次
# ----------------------------------------
# 【col: 别墅类型_is_独栋】
#   - 0: 261025 次
#   - 1: 134 次
# ----------------------------------------
# 【col: 别墅类型_is_联排】
#   - 0: 260991 次
#   - 1: 168 次
# ----------------------------------------
# 【col: 别墅类型_is_叠拼】
#   - 0: 261051 次
#   - 1: 108 次
# ----------------------------------------
# 【col: 别墅类型_is_双拼】
#   - 0: 261142 次
#   - 1: 17 次
# ----------------------------------------
# 【col: 交易权属_is_私产】
#   - 0: 259437 次
#   - 1: 1722 次
# ----------------------------------------
# 【col: 交易权属_is_商品房】
#   - 1: 206007 次
#   - 0: 55152 次
# ----------------------------------------
# 【col: 交易权属_is_已购公房】
#   - 0: 225892 次
#   - 1: 35267 次
# ----------------------------------------
# 【col: 交易权属_is_一类经济适用房】
#   - 0: 254593 次
#   - 1: 6566 次
# ----------------------------------------
# 【col: 交易权属_is_二类经济适用房】
#   - 0: 253172 次
#   - 1: 7987 次
# ----------------------------------------
# 【col: 交易权属_is_央产房】
#   - 0: 258134 次
#   - 1: 3025 次
# ----------------------------------------
# 【col: 交易权属_is_限价商品房】
#   - 0: 254930 次
#   - 1: 6229 次
# ----------------------------------------
# 【col: 交易权属_is_定向安置房】
#   - 0: 260574 次
#   - 1: 585 次
# ----------------------------------------
# 【col: 交易权属_is_自住型商品房】
#   - 0: 260289 次
#   - 1: 870 次
# ----------------------------------------
# 【col: 房屋用途_is_普通住宅】
#   - 1: 246217 次
#   - 0: 14942 次
# ----------------------------------------
# 【col: 房屋用途_is_别墅】
#   - 0: 260603 次
#   - 1: 556 次
# ----------------------------------------
# 【col: 房屋用途_is_车库】
#   - 0: 259374 次
#   - 1: 1785 次
# ----------------------------------------
# 【col: 房屋用途_is_商业办公类】
#   - 0: 252547 次
#   - 1: 8612 次
# ----------------------------------------
# 【col: 房屋用途_is_公寓】
#   - 0: 257224 次
#   - 1: 3935 次
# ----------------------------------------
# 【col: 房屋用途_is_住宅】
#   - 1: 246354 次
#   - 0: 14805 次
# ----------------------------------------
# 【col: 房屋用途_is_酒店式公寓】
#   - 0: 260750 次
#   - 1: 409 次
# ----------------------------------------
# 【col: 房屋用途_is_平房】
#   - 0: 261139 次
#   - 1: 20 次
# ----------------------------------------
# 【col: 房屋用途_is_商务型公寓】
#   - 0: 260922 次
#   - 1: 237 次
# ----------------------------------------
# 【col: 房屋用途_is_公寓（住宅）】
#   - 0: 261105 次
#   - 1: 54 次
# ----------------------------------------
# 【col: 房屋用途_is_服务式公寓】
#   - 0: 261149 次
#   - 1: 10 次
# ----------------------------------------
# 【col: 房屋用途_is_四合院】
#   - 0: 261125 次
#   - 1: 34 次
# ----------------------------------------
# 【col: 房屋用途_is_住宅式公寓】
#   - 0: 261156 次
#   - 1: 3 次
# ----------------------------------------
# 【col: 房屋用途_is_单身公寓（住宅）】
#   - 0: 261154 次
#   - 1: 5 次
# ----------------------------------------
# 【col: 房屋年限_is_满五年】
#   - 1: 190247 次
#   - 0: 70912 次
# ----------------------------------------
# 【col: 房屋年限_is_满两年】
#   - 0: 190433 次
#   - 1: 70726 次
# ----------------------------------------
# 【col: 房屋年限_is_未满两年】
#   - 0: 233206 次
#   - 1: 27953 次
# ----------------------------------------
# 【col: 房源标签_is_VR看装修】
#   - 0: 146329 次
#   - 1: 114830 次
# ----------------------------------------
# 【col: 房源标签_is_房本满五年】
#   - 1: 190267 次
#   - 0: 70892 次
# ----------------------------------------
# 【col: 房源标签_is_VR房源】
#   - 0: 167539 次
#   - 1: 93620 次
# ----------------------------------------
# 【col: 房源标签_is_地铁】
#   - 0: 141064 次
#   - 1: 120095 次
# ----------------------------------------
# 【col: 房源标签_is_随时看房】
#   - 0: 195690 次
#   - 1: 65469 次
# ----------------------------------------
# 【col: 房源标签_is_房本满两年】
#   - 0: 218386 次
#   - 1: 42773 次
# ----------------------------------------
# 【col: category_is_Others】
#   - 1: 200482 次
#   - 0: 60677 次
# ----------------------------------------
# 【col: category_is_High-Tech】
#   - 0: 221508 次
#   - 1: 39651 次
# ----------------------------------------
# 【col: category_is_General-Mfg】
#   - 0: 256692 次
#   - 1: 4467 次
# ----------------------------------------
# 【col: category_is_Heavy-Nuisance】
#   - 0: 256907 次
#   - 1: 4252 次
# ----------------------------------------
# 【col: category_is_Modern-Service】
#   - 0: 248852 次
#   - 1: 12307 次
# ----------------------------------------

# %%
from econml.dml import LinearDML
from econml.cate_interpreter import SingleTreeCateInterpreter

Y = stats['log_unit_price']
T = stats['nearest_park_dist_km']


base_cols = ['distance_to_center', 'area']
cat_cols = [col for col in stats.columns if col.startswith('category_is_')]
X_cols = base_cols + cat_cols
X = stats[X_cols]


exclude_cols = X_cols + ['log_unit_price', 'nearest_park_dist_km', 'price', 'unit_price', 'log_price']
W_cols = [col for col in stats.columns if col not in exclude_cols]
W = stats[W_cols]

# %%
W_cols
# Out:
# ['配备电梯',
#  '产权所属',
#  'rooms',
#  'halls',
#  'kitchens',
#  'bathrooms',
#  '看房时间_is_只周末可看',
#  '看房时间_is_下班后可看',
#  '看房时间_is_提前预约随时可看',
#  '看房时间_is_有租户需预约',
#  'total_floors',
#  'floor_level_is_低楼层',
#  'floor_level_is_底层',
#  'floor_level_is_高楼层',
#  'floor_level_is_中楼层',
#  'floor_level_is_顶层',
#  'floor_level_is_地下室',
#  '房屋朝向_is_南',
#  '房屋朝向_is_北',
#  '房屋朝向_is_东',
#  '房屋朝向_is_西',
#  '房屋朝向_is_西北',
#  '房屋朝向_is_西南',
#  '房屋朝向_is_东南',
#  '房屋朝向_is_东北',
#  '建筑结构_is_钢混结构',
#  '建筑结构_is_混合结构',
#  '建筑结构_is_未知结构',
#  '建筑结构_is_砖混结构',
#  '建筑结构_is_钢结构',
#  '建筑结构_is_砖木结构',
#  '建筑结构_is_框架结构',
#  '装修情况_is_精装',
#  '装修情况_is_简装',
#  '装修情况_is_毛坯',
#  '装修情况_is_其它',
#  '装修情况_is_其他',
#  'elevators',
#  'households',
#  'elevators_household_ratio',
#  '别墅类型_is_非别墅',
#  '别墅类型_is_独栋',
#  '别墅类型_is_联排',
#  '别墅类型_is_叠拼',
#  '别墅类型_is_双拼',
#  '交易权属_is_私产',
#  '交易权属_is_商品房',
#  '交易权属_is_已购公房',
#  '交易权属_is_一类经济适用房',
#  '交易权属_is_二类经济适用房',
#  '交易权属_is_央产房',
#  '交易权属_is_限价商品房',
#  '交易权属_is_定向安置房',
#  '交易权属_is_自住型商品房',
#  '房屋用途_is_普通住宅',
#  '房屋用途_is_别墅',
#  '房屋用途_is_车库',
#  '房屋用途_is_商业办公类',
#  '房屋用途_is_公寓',
#  '房屋用途_is_住宅',
#  '房屋用途_is_酒店式公寓',
#  '房屋用途_is_平房',
#  '房屋用途_is_商务型公寓',
#  '房屋用途_is_公寓（住宅）',
#  '房屋用途_is_服务式公寓',
#  '房屋用途_is_四合院',
#  '房屋用途_is_住宅式公寓',
#  '房屋用途_is_单身公寓（住宅）',
#  '房屋年限_is_满五年',
#  '房屋年限_is_满两年',
#  '房屋年限_is_未满两年',
#  '房源标签_is_VR看装修',
#  '房源标签_is_房本满五年',
#  '房源标签_is_VR房源',
#  '房源标签_is_地铁',
#  '房源标签_is_随时看房',
#  '房源标签_is_房本满两年']

# %%
T_log = np.log1p(T)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

features = pd.concat([X, W], axis=1)

scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)
features_scaled = pd.DataFrame(features_scaled, columns=features.columns)

print("数据标准化完成")
print(f"特征数量: {features_scaled.shape[1]}")
# Out:
# 数据标准化完成
# 特征数量: 84

# %%
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

def objective(trial, X_full, y_full):
    alpha = trial.suggest_float('alpha', 1e-5, 10.0, log=True)
    
    model = LassoCV(
        alphas=[alpha],
        cv=3,
        max_iter=10000,
        random_state=42,
        n_jobs=-1
    )
    
    model.fit(X_full, y_full)
    
    score = model.score(X_full, y_full)
    
    return score

SEED = 42
sampler = optuna.samplers.TPESampler(seed=SEED)

print("🚀 正在优化 Model_Y (房价预测)...")
study_y = optuna.create_study(direction='maximize', sampler=sampler)
study_y.optimize(lambda trial: objective(trial, features_scaled, Y), n_trials=20)
best_alpha_y = study_y.best_params['alpha']

print("\n🚀 正在优化 Model_T (干预项预测)...")
study_t = optuna.create_study(direction='maximize', sampler=sampler)
study_t.optimize(lambda trial: objective(trial, features_scaled, T_log), n_trials=20)
best_alpha_t = study_t.best_params['alpha']

print("-" * 30)
print(f"Model_Y 最佳 alpha: {best_alpha_y:.6f}, R²: {study_y.best_value:.4f}")
print(f"Model_T 最佳 alpha: {best_alpha_t:.6f}, R²: {study_t.best_value:.4f}")
# Out:
# 🚀 正在优化 Model_Y (房价预测)...
#
# 🚀 正在优化 Model_T (干预项预测)...
# ------------------------------
# Model_Y 最佳 alpha: 0.000010, R²: 0.6916
# Model_T 最佳 alpha: 0.000011, R²: 0.1797

# %%
from sklearn.linear_model import Lasso

model_y = Lasso(
    alpha=best_alpha_y,
    max_iter=10000,
    random_state=42
)

model_t = Lasso(
    alpha=best_alpha_t,
    max_iter=10000,
    random_state=42
)

print("Lasso 模型创建完成")
# Out:
# Lasso 模型创建完成

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']  
plt.rcParams['axes.unicode_minus'] = False

model_y.fit(features_scaled, Y)
model_t.fit(features_scaled, T_log)

print("Model_Y 训练完成")
print("Model_T 训练完成")

feature_importance_y = pd.DataFrame({
    'feature': features.columns,
    'coefficient': model_y.coef_
}).sort_values(by='coefficient', key=abs, ascending=False)

feature_importance_t = pd.DataFrame({
    'feature': features.columns,
    'coefficient': model_t.coef_
}).sort_values(by='coefficient', key=abs, ascending=False)

print("\n=== Model_Y 特征重要性 (Top 20) ===")
print(feature_importance_y.head(20))

print("\n=== Model_T 特征重要性 (Top 20) ===")
print(feature_importance_t.head(20))
# Out:
# Model_Y 训练完成
# Model_T 训练完成
#
# === Model_Y 特征重要性 (Top 20) ===
#                       feature  coefficient
# 0          distance_to_center    -0.372317
# 61               房屋用途_is_普通住宅     0.103691
# 63                 房屋用途_is_车库    -0.101485
# 1                        area    -0.060727
# 12                  bathrooms     0.060272
# 81                 房源标签_is_地铁     0.044991
# 7                        配备电梯     0.044979
# 65                 房屋用途_is_公寓     0.042595
# 62                 房屋用途_is_别墅     0.037702
# 33               建筑结构_is_混合结构    -0.034665
# 58              交易权属_is_限价商品房    -0.031736
# 55            交易权属_is_一类经济适用房    -0.031234
# 17               total_floors    -0.031090
# 64              房屋用途_is_商业办公类    -0.030998
# 40                 装修情况_is_简装    -0.030068
# 57                交易权属_is_央产房     0.026281
# 11                   kitchens     0.026037
# 45                 households     0.021224
# 54               交易权属_is_已购公房     0.019953
# 46  elevators_household_ratio     0.019372
#
# === Model_T 特征重要性 (Top 20) ===
#                feature  coefficient
# 0   distance_to_center     0.103889
# 33        建筑结构_is_混合结构    -0.017842
# 2   category_is_Others     0.013541
# 81          房源标签_is_地铁    -0.012178
# 42          装修情况_is_其它    -0.011298
# 53         交易权属_is_商品房    -0.011264
# 44           elevators    -0.010100
# 58       交易权属_is_限价商品房     0.009756
# 34        建筑结构_is_未知结构     0.009540
# 10               halls    -0.009507
# 9                rooms     0.009368
# 45          households     0.007971
# 24           房屋朝向_is_南     0.007243
# 17        total_floors    -0.006632
# 56     交易权属_is_二类经济适用房     0.006085
# 66          房屋用途_is_住宅     0.005658
# 19   floor_level_is_底层     0.005648
# 29          房屋朝向_is_西南    -0.005593
# 11            kitchens     0.005486
# 75         房屋年限_is_满五年    -0.004976

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 10))

top_n = 20

ax1 = axes[0]
top_features_y = feature_importance_y.head(top_n)
colors_y = ['#2ecc71' if c > 0 else '#e74c3c' for c in top_features_y['coefficient']]
bars1 = ax1.barh(range(len(top_features_y)), top_features_y['coefficient'].values, color=colors_y)
ax1.set_yticks(range(len(top_features_y)))
ax1.set_yticklabels(top_features_y['feature'].values)
ax1.invert_yaxis()
ax1.set_xlabel('Coefficient')
ax1.set_title(f'Model_Y (房价预测) - Lasso 特征重要性 (Top {top_n})')
ax1.axvline(x=0, color='black', linestyle='-', linewidth=0.5)

ax2 = axes[1]
top_features_t = feature_importance_t.head(top_n)
colors_t = ['#2ecc71' if c > 0 else '#e74c3c' for c in top_features_t['coefficient']]
bars2 = ax2.barh(range(len(top_features_t)), top_features_t['coefficient'].values, color=colors_t)
ax2.set_yticks(range(len(top_features_t)))
ax2.set_yticklabels(top_features_t['feature'].values)
ax2.invert_yaxis()
ax2.set_xlabel('Coefficient')
ax2.set_title(f'Model_T (干预项预测) - Lasso 特征重要性 (Top {top_n})')
ax2.axvline(x=0, color='black', linestyle='-', linewidth=0.5)

plt.tight_layout()
plt.savefig('lasso_feature_importance.png', dpi=150, bbox_inches='tight')
plt.show()

print("\n特征重要性图已保存至 lasso_feature_importance.png")
# Out:
# 特征重要性图已保存至 lasso_feature_importance.png

# %%
from econml.dml import LinearDML

est = LinearDML(
    model_y=model_y,
    model_t=model_t,
    discrete_treatment=False,
    cv=5,
    random_state=42
)

est.fit(Y, T_log, X=X, W=W, inference='statsmodels')

print("LinearDML 模型训练完成")
# Out:
# LinearDML 模型训练完成

# %%
intrp = SingleTreeCateInterpreter(max_depth=3, min_samples_leaf=100)
intrp.interpret(est, X)

plt.figure(figsize=(16, 9))
intrp.plot(feature_names=X_cols)
plt.title("Industrial Park Distance Impact Heterogeneity (CATE Tree) - Lasso")
plt.show()

# %%
print(est.summary())
# Out:
#                                Coefficient Results
# =================================================================================
#                            point_estimate stderr  zstat  pvalue ci_lower ci_upper
# ---------------------------------------------------------------------------------
# distance_to_center                  0.007    0.0  45.155    0.0    0.007    0.008
# area                                  0.0    0.0   1.211  0.226     -0.0    0.001
# category_is_Others                 -0.063  0.007  -9.476    0.0   -0.076    -0.05
# category_is_High-Tech               0.014  0.009   1.537  0.124   -0.004    0.031
# category_is_General-Mfg            -0.246  0.015 -16.172    0.0   -0.276   -0.217
# category_is_Heavy-Nuisance         -0.004  0.015   -0.24   0.81   -0.033    0.026
# category_is_Modern-Service          0.143  0.011  13.007    0.0    0.122    0.165
#                        CATE Intercept Results
# ====================================================================
#                point_estimate stderr zstat  pvalue ci_lower ci_upper
# --------------------------------------------------------------------
# cate_intercept         -0.157  0.015 -10.52    0.0   -0.186   -0.127
# --------------------------------------------------------------------
#
# <sub>A linear parametric conditional average treatment effect (CATE) model was fitted:
# $Y = \Theta(X)\cdot T + g(X, W) + \epsilon$
# where for every outcome $i$ and treatment $j$ the CATE $\Theta_{ij}(X)$ has the form:
# $\Theta_{ij}(X) = X' coef_{ij} + cate\_intercept_{ij}$
# Coefficient Results table portrays the $coef_{ij}$ parameter vector for each outcome $i$ and treatment $j$. Intercept Results table portrays the $cate\_intercept_{ij}$ parameter.</sub>
